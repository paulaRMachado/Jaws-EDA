# %%
import src.aquire_data as aquire
import src.clean as clean
import src.visualization as viz

# %%
df = aquire.aquire_data("global_shark_attacks")

# %%
df_clean = clean.basic_cleaning(df)

# %%
viz.visualizing_1(df_clean)

# %%
viz.visualizing_2(df_clean)

# %%
viz.visualizing_3(df_clean)

# %%
viz.visualizing_4(df_clean)

# %%
viz.visualizing_5(df_clean)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 viz.visualizing_5(df_clean)
#
# File c:\Users\PaulaMachado\Documents\PESSOAL\IRONHACK\PROJECTS\Jaws-EDA\src\visualization.py:47, in visualizing_5(jaws)
#      45 def visualizing_5 (jaws):
#      46     ### Deaths in history
# ---> 47     death_hist = sbn.lineplot(data =hist_df, x="year", y="number_deaths", estimator="sum").set(title="Deaths per year involving sharks from 1900 to 2020")
#      48     mplot.savefig("images/history_of_death.png", dpi=100)
#      49     os.system(f"open images/history_of_death.png")
#
# NameError: name 'hist_df' is not defined

# %%
viz.visualizing_6(df_clean)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 viz.visualizing_6(df_clean)
#
# File c:\Users\PaulaMachado\Documents\PESSOAL\IRONHACK\PROJECTS\Jaws-EDA\src\visualization.py:53, in visualizing_6(jaws)
#      51 def visualizing_6 (jaws):
#      52     ## Deaths of women per continent
# ---> 53     women_death_continent= sbn.countplot(data=df_death_women, x= df_death_women["fatal"], hue=df_death_women["continent"], palette="rocket", hue_order=["OCEANIA", "NORTH AMERICA","EUROPE","AFRICA","ASIA","CENTRAL AMERICA","SOUTH AMERICA"])
#      54     women_death_continent.set(xlabel='Continents', title="Women's deaths per continent", ylabel= 'Number of deaths')
#      55     women_death_continent.figure.savefig("images/Womens_deaths_per_continent.png", dpi=100)
#
# NameError: name 'df_death_women' is not defined
